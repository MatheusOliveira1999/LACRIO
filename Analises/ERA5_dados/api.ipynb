# %%
import cdsapi
import os

client = cdsapi.Client()
dataset = "reanalysis-era5-single-levels"

# Define output directory
output_dir = "/home/matheus/Documentos/GitHub/LACRIO/Analises/ERA5_dados/dados_era5_03"
os.makedirs(output_dir, exist_ok=True)

# Define years, all months, all days
years = [str(y) for y in range(1968, 2021)]  # Ajuste conforme desejado
months = [f"{m:02d}" for m in range(1, 13)]  # "01" a "12"
days = [f"{d:02d}" for d in range(1, 32)]    # "01" a "31"
times = ["00:00", "06:00", "12:00", "18:00"]

area = [-8.5, -77.9, -9.9, -77]  # North, West, South, East

# Loop through each year
for year in years:
    request_common = {
        "product_type": "reanalysis",
        "data_format": "netcdf",
        "download_format": "unarchived",
        "year": year,
        "month": months,
        "day": days,
        "time": times,
        "area": area
    }

    # Instantaneous variables
    request_ins = request_common.copy()
    request_ins["variable"] = [
        "10m_u_component_of_wind",
        "10m_v_component_of_wind",
        "2m_dewpoint_temperature",
        "2m_temperature",
        "surface_pressure",
        "geopotential"
    ]
    
    target_ins = os.path.join(output_dir, f"ERA5_{year}_ins.nc")
    print(f"Downloading {target_ins}...")
    client.retrieve(dataset, request_ins, target_ins)

    # Accumulated variables
    request_accum = request_common.copy()
    request_accum["variable"] = [
        "total_precipitation",
        "surface_solar_radiation_downwards",
        "surface_thermal_radiation_downwards",
        "snowfall"
    ]

    target_accum = os.path.join(output_dir, f"ERA5_{year}_accum.nc")
    print(f"Downloading {target_accum}...") 
    client.retrieve(dataset, request_accum, target_accum)
# Out:
# 2025-05-26 20:20:26,935 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-05-26 20:20:26,936 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# ...
# 2025-05-26 20:20:28,665 INFO Request ID is 76f9a182-e7f7-4893-83be-d5258438a747
# 2025-05-26 20:20:28,935 INFO status has been updated to accepted
# 2025-05-26 20:21:47,538 INFO status has been updated to successful
# ...
# 2025-05-26 20:22:02,475 INFO Request ID is b7a8962b-47c1-48d7-8f39-7ee5f66f19fc
# 2025-05-26 20:22:03,268 INFO status has been updated to accepted
# 2025-05-26 20:22:10,067 INFO status has been updated to running
# 2025-05-26 20:22:13,740 INFO status has been updated to accepted
# ...

# %%
import cdsapi
import os

# Diretório de saída
output_dir = "dados_era5"
os.makedirs(output_dir, exist_ok=True)

# Dataset e parâmetros
dataset = "reanalysis-era5-pressure-levels"
anos = [str(ano) for ano in range(1940, 2026)]
meses = [f"{m:02d}" for m in range(1, 13)]

# Template base da requisição
def get_request_template(dias):
    return {
        "product_type": "reanalysis",
        "variable": [
            "geopotential",
            "specific_humidity",
            "specific_rain_water_content",
            "temperature",
            "u_component_of_wind",
            "v_component_of_wind"
        ],
        "day": dias,
        "time": [f"{h:02d}:00" for h in range(24)],
        "pressure_level": ["300", "400", "500"],
        "format": "netcdf",
        "area": [-8.5, -77.9, -9.9, -77],
    }

# Inicializa cliente
client = cdsapi.Client()

# Loop principal
for ano in anos:
    for mes in meses:
        output_file = os.path.join(output_dir, f"era5_{ano}_{mes}.nc")

        if os.path.exists(output_file):
            print(f"Arquivo já existe: {output_file}, pulando download.")
            continue

        print(f"Tentando baixar dados para {ano}-{mes}...")

        # Requisição completa (dia 01 ao 31)
        try:
            request = get_request_template([f"{d:02d}" for d in range(1, 32)])
            request["year"] = ano
            request["month"] = mes

            client.retrieve(dataset, request, output_file)
            print(f"✅ Sucesso: {output_file}")
            continue

        except Exception as e:
            print(f"⚠️ Falha no mês completo: {e}")
            print("➡️ Tentando dividir o mês em duas partes...")

        # Divisão: dias 1–15
        try:
            output_file_half1 = os.path.join(output_dir, f"era5_{ano}_{mes}_part1.nc")
            request_half1 = get_request_template([f"{d:02d}" for d in range(1, 16)])
            request_half1["year"] = ano
            request_half1["month"] = mes

            client.retrieve(dataset, request_half1, output_file_half1)
            print(f"✅ Parte 1 salva: {output_file_half1}")
        except Exception as e1:
            print(f"❌ Falha na Parte 1: {e1}")

        # Divisão: dias 16–31
        try:
            output_file_half2 = os.path.join(output_dir, f"era5_{ano}_{mes}_part2.nc")
            request_half2 = get_request_template([f"{d:02d}" for d in range(16, 32)])
            request_half2["year"] = ano
            request_half2["month"] = mes

            client.retrieve(dataset, request_half2, output_file_half2)
            print(f"✅ Parte 2 salva: {output_file_half2}")
        except Exception as e2:
            print(f"❌ Falha na Parte 2: {e2}")
# Out:
# 2025-04-29 11:52:32,520 WARNING [2025-04-29T00:00:00] Multiple maintenance sessions are planned this week, which may affect data downloads and other services. Check [here](https://status.ecmwf.int/) for status updates.
# 2025-04-29 11:52:32,522 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-04-29 11:52:32,523 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# Arquivo já existe: dados_era5/era5_1940_01.nc, pulando download.
# Arquivo já existe: dados_era5/era5_1940_02.nc, pulando download.
# Arquivo já existe: dados_era5/era5_1940_03.nc, pulando download.
# Arquivo já existe: dados_era5/era5_1940_04.nc, pulando download.
# ...

# %%
import cdsapi
import os

client = cdsapi.Client()
dataset = "reanalysis-era5-single-levels"

# Diretório de saída
output_dir = "ERA5"
os.makedirs(output_dir, exist_ok=True)

# Anos, meses, dias, horas
years = [str(y) for y in range(1940, 2020)]
months = [f"{m:02d}" for m in range(1, 13)]
days = [f"{d:02d}" for d in range(1, 32)]
times = ["00:00", "06:00", "12:00", "18:00"]
area = [-8, -74, -9, -73]  # N, W, S, E

for year in years:
    # Solicitação para variáveis instantâneas
    request_ins = {
        "product_type": "reanalysis",
        "format": "netcdf",
        "variable": [
            "10m_u_component_of_wind",
            "10m_v_component_of_wind",
            "2m_dewpoint_temperature",
            "2m_temperature",
            "surface_pressure",
            "geopotential"
        ],
        "year": year,
        "month": months,
        "day": days,
        "time": times,
        "area": area
    }

    target_ins = os.path.join(output_dir, f"ERA5_{year}_ins.nc")
    print(f"Baixando {target_ins}...")
    client.retrieve(dataset, request_ins, target_ins)

    # Solicitação para variáveis acumuladas
    request_accum = {
        "product_type": "reanalysis",
        "format": "netcdf",
        "variable": [
            "total_precipitation",
            "surface_solar_radiation_downwards",
            "surface_thermal_radiation_downwards",
            "snowfall"
        ],
        "year": year,
        "month": months,
        "day": days,
        "time": times,
        "area": area
    }

    target_accum = os.path.join(output_dir, f"ERA5_{year}_accum.nc")
    print(f"Baixando {target_accum}...")
    client.retrieve(dataset, request_accum, target_accum)
    print(f"Download completo para {year}.")
    print("Todos os downloads concluídos.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import cdsapi
#       2 import os
# ----> 4 client = cdsapi.Client()
#       5 dataset = "reanalysis-era5-single-levels"
#       7 # Diretório de saída
#
# File ~/miniconda3/envs/estudos/lib/python3.10/site-packages/cdsapi/api.py:281, in Client.__new__(cls, url, key, *args, **kwargs)
#     280 def __new__(cls, url=None, key=None, *args, **kwargs):
# --> 281     _, token, _ = get_url_key_verify(url, key, None)
#     282     if ":" in token:
#     283         return super().__new__(cls)
#
# File ~/miniconda3/envs/estudos/lib/python3.10/site-packages/cdsapi/api.py:69, in get_url_key_verify(url, key, verify)
#      66             verify = bool(int(config.get("verify", 1)))
#      68 if url is None or key is None or key is None:
# ...
